# %%
import pandas as pd
df = pd.read_csv("data/conflicts_tur_syr_22.csv", delimiter = ",")
df
# Out:
#       event_id_cnty        event_date  year  time_precision  \
# 0         SYR109663  31 December 2022  2022               1
# 1         SYR109664  31 December 2022  2022               2
# 2         SYR109665  31 December 2022  2022               1
# 3         SYR109685  31 December 2022  2022               1
# 4         SYR109693  31 December 2022  2022               1
# ...             ...               ...   ...             ...
# 11125      SYR97623   01 January 2022  2022               1
# 11126      SYR97627   01 January 2022  2022               1
# 11127      SYR97626   01 January 2022  2022               1
# 11128      SYR97628   01 January 2022  2022               1
# 11129      SYR97614   01 January 2022  2022               1
#
#             disorder_type                  event_type  \
# 0      Political violence  Violence against civilians
# 1      Political violence  Violence against civilians
# 2      Political violence  Violence against civilians
# ...

# %%
# Split date into day and month
df["event_date"] = pd.to_datetime(df["event_date"])
df['day'] = df ['event_date'].dt.day 
df ['month'] = df ['event_date'].dt.month
df = df.drop("event_date", axis=1)
df
# Out:
#       event_id_cnty  year  time_precision       disorder_type  \
# 0         SYR109663  2022               1  Political violence
# 1         SYR109664  2022               2  Political violence
# 2         SYR109665  2022               1  Political violence
# 3         SYR109685  2022               1  Political violence
# 4         SYR109693  2022               1  Political violence
# ...             ...   ...             ...                 ...
# 11125      SYR97623  2022               1  Political violence
# 11126      SYR97627  2022               1  Political violence
# 11127      SYR97626  2022               1  Political violence
# 11128      SYR97628  2022               1  Political violence
# 11129      SYR97614  2022               1  Political violence
#
#                        event_type                  sub_event_type  \
# 0      Violence against civilians  Abduction/forced disappearance
# 1      Violence against civilians  Abduction/forced disappearance
# ...

# %%
# Extract relevan columns
important_cols = ["event_id_cnty", "day","month","year","location", "latitude", "longitude"]
interesting_data = df[important_cols]
interesting_data
# Out:
#       event_id_cnty  day  month  year         location  latitude  longitude
# 0         SYR109663   31     12  2022            Afrin   36.5111    36.8655
# 1         SYR109664   31     12  2022        Jandairis   36.3925    36.6896
# 2         SYR109665   31     12  2022        Hole Camp   36.3768    41.1333
# 3         SYR109685   31     12  2022        Al Shanan   34.9708    40.5641
# 4         SYR109693   31     12  2022           Menbij   36.5258    37.9510
# ...             ...  ...    ...   ...              ...       ...        ...
# 11125      SYR97623    1      1  2022       Al-Rasafah   35.6288    38.7581
# 11126      SYR97627    1      1  2022            Idleb   35.9290    36.6353
# 11127      SYR97626    1      1  2022        Ithariyah   35.3652    37.7886
# 11128      SYR97628    1      1  2022  Jabal al-Zawiya   35.7197    36.5418
# 11129      SYR97614    1      1  2022   Al-Asbah farms   35.3219    40.2921
#
# [11130 rows x 7 columns]

# %%
# Export to CSV to be exported to GEOJSON in QGIS
#interesting_data.to_csv("data/Conflicts_Syr_Tur_2022.csv", sep=',')

# %%
#import geopandas 
#df_con = geopandas.read_file("data/Conflicts_Syr_Tur_2022.geojson")
#df_con = df_con[df_con.month == 1]
#df_con
# Out:
#        field_1 event_id_cnty  day  month  year         location  latitude  \
# 0            0     SYR109663   31     12  2022            Afrin   36.5111
# 1            1     SYR109664   31     12  2022        Jandairis   36.3925
# 2            2     SYR109665   31     12  2022        Hole Camp   36.3768
# 3            3     SYR109685   31     12  2022        Al Shanan   34.9708
# 4            4     SYR109693   31     12  2022           Menbij   36.5258
# ...        ...           ...  ...    ...   ...              ...       ...
# 11125    11125      SYR97623    1      1  2022       Al-Rasafah   35.6288
# 11126    11126      SYR97627    1      1  2022            Idleb   35.9290
# 11127    11127      SYR97626    1      1  2022        Ithariyah   35.3652
# 11128    11128      SYR97628    1      1  2022  Jabal al-Zawiya   35.7197
# 11129    11129      SYR97614    1      1  2022   Al-Asbah farms   35.3219
#
#        longitude                   geometry
# ...

# %%
#import fiona
#df_con.to_file('Conflicts_Syr_Tur_0922.geojson', driver='GeoJSON')
