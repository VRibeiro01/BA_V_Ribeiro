# %%
import geopandas

# Extract only active camps from dataset
df = geopandas.read_file("data/turkey_camps_2023.geojson")
df = df[df.Status == 'ACTIVE'] 
df
# Out:
#    cmp_id     cmp_tr     cmp_en                     Type  Status  \
# 1     C02  YAYLADAĞI  YAYLADAGI             Refugee Camp  ACTIVE
# 3     C04   ALTINÖZÜ   ALTINOZU             Refugee Camp  ACTIVE
# 5     C06    APAYDIN    APAYDIN  Military Defactors Camp  ACTIVE
# 6     C07    SARIÇAM    SARICAM             Refugee Camp  ACTIVE
# 13    C14   TÜRKOĞLU   TURKOGLU             Refugee Camp  ACTIVE
# 15    C16    ELBEYLİ    ELBEYLI             Refugee Camp  ACTIVE
# 18    C19  CEVDETIYE  CEVDETIYE             Refugee Camp  ACTIVE
#
#          adm2_tr       adm2_en  adm2_code  adm1        adm1_tr        adm1_en  \
# 1      YAYLADAĞI     YAYLADAGI  TUR031015  31.0          HATAY          HATAY
# 3       ALTINÖZÜ      ALTINOZU  TUR031001  31.0          HATAY          HATAY
# 5        ANTAKYA       ANTAKYA  TUR031002  31.0          HATAY          HATAY
# 6        SARIÇAM       SARICAM  TUR001011   1.0          ADANA          ADANA
# ...

# %%
import fiona
df.to_file('active_turkey_camps.geojson', driver='GeoJSON')

# %%
# Merge Tukish refugee camps with Syrian IDP camps
#df1 = geopandas.read_file("data/idp_sites.geojson")
#df1
# Out:
#     Description Country                  ADM1           ADM2           ADM3  \
# 0      IDP Camp   Syria         Al Qunaytirah  Al Qunaytirah  Al Qunaytirah
# 1      IDP Camp   Syria           As Suwayda'    As Suwayda'    As Suwayda'
# 2      IDP Camp   Syria           As Suwayda'    As Suwayda'    As Suwayda'
# 3      IDP Camp   Syria  Damascus Countryside           Duma      Sabe Byar
# 4      IDP Camp   Syria  Damascus Countryside           Duma      Sabe Byar
# ..          ...     ...                   ...            ...            ...
# 96          NaN     NaN                   NaN            NaN            NaN
# 97          NaN     NaN                   NaN            NaN            NaN
# 98          NaN     NaN                   NaN            NaN            NaN
# 99          NaN     NaN                   NaN            NaN            NaN
# 100         NaN     NaN                   NaN            NaN            NaN
#
# ...

# %%
#df2 = df.merge(df1, on='NAME').drop_duplicates(subset=['NAME'])
